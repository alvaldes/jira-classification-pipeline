# %%
import pandas as pd

# Load the CSV file
df = pd.read_csv('hbase-0.95.2.csv')

df.head()
# Out:
#                                                 File  CountDeclMethodPrivate  \
# 0  dev-support/jenkins-tools/buildstats/src/main/...                       0
# 1  dev-support/jenkins-tools/buildstats/src/main/...                       0
# 2  dev-support/jenkins-tools/buildstats/src/main/...                       0
# 3  dev-support/jenkins-tools/buildstats/src/main/...                       1
# 4  dev-support/jenkins-tools/buildstats/src/main/...                       0
#
#    AvgLineCode  CountLine  MaxCyclomatic  CountDeclMethodDefault  \
# 0            3         49              1                       0
# 1            6         87              8                       0
# 2            3         61              1                       0
# 3           21        260             18                       3
# 4            3         47              1                       0
#
#    AvgEssential  CountDeclClassVariable  SumCyclomaticStrict  AvgCyclomatic  \
# 0             1                       0                    5              1
# 1             1                       0                   15              2
# 2             1                       0                    9              1
# 3             2                       5                   43              5
# 4             1                       0                    5              1
#
#    ...  OWN_LINE  OWN_COMMIT  MINOR_COMMIT  MINOR_LINE  MAJOR_COMMIT  \
# 0  ...       1.0         1.0             0           1             1
# 1  ...       1.0         1.0             0           1             1
# 2  ...       1.0         1.0             0           1             1
# 3  ...       1.0         1.0             0           1             1
# 4  ...       1.0         1.0             0           1             1
#
#    MAJOR_LINE  HeuBug  HeuBugCount  RealBug  RealBugCount
# 0           0   False            0    False             0
# 1           0   False            0    False             0
# 2           0   False            0    False             0
# 3           0   False            0    False             0
# 4           0   False            0    False             0
#
# [5 rows x 70 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1834 entries, 0 to 1833
# Data columns (total 70 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   File                       1834 non-null   object
#  1   CountDeclMethodPrivate     1834 non-null   int64
#  2   AvgLineCode                1834 non-null   int64
#  3   CountLine                  1834 non-null   int64
#  4   MaxCyclomatic              1834 non-null   int64
#  5   CountDeclMethodDefault     1834 non-null   int64
#  6   AvgEssential               1834 non-null   int64
#  7   CountDeclClassVariable     1834 non-null   int64
#  8   SumCyclomaticStrict        1834 non-null   int64
#  9   AvgCyclomatic              1834 non-null   int64
#  10  AvgLine                    1834 non-null   int64
#  11  CountDeclClassMethod       1834 non-null   int64
#  12  AvgLineComment             1834 non-null   int64
#  13  AvgCyclomaticModified      1834 non-null   int64
#  14  CountDeclFunction          1834 non-null   int64
#  15  CountLineComment           1834 non-null   int64
#  16  CountDeclClass             1834 non-null   int64
#  17  CountDeclMethod            1834 non-null   int64
#  18  SumCyclomaticModified      1834 non-null   int64
#  19  CountLineCodeDecl          1834 non-null   int64
#  20  CountDeclMethodProtected   1834 non-null   int64
#  21  CountDeclInstanceVariable  1834 non-null   int64
#  22  MaxCyclomaticStrict        1834 non-null   int64
#  23  CountDeclMethodPublic      1834 non-null   int64
#  24  CountLineCodeExe           1834 non-null   int64
#  25  SumCyclomatic              1834 non-null   int64
#  26  SumEssential               1834 non-null   int64
#  27  CountStmtDecl              1834 non-null   int64
#  28  CountLineCode              1834 non-null   int64
#  29  CountStmtExe               1834 non-null   int64
#  30  RatioCommentToCode         1834 non-null   float64
#  31  CountLineBlank             1834 non-null   int64
#  32  CountStmt                  1834 non-null   int64
#  33  MaxCyclomaticModified      1834 non-null   int64
#  34  CountSemicolon             1834 non-null   int64
#  35  AvgLineBlank               1834 non-null   int64
#  36  CountDeclInstanceMethod    1834 non-null   int64
#  37  AvgCyclomaticStrict        1834 non-null   int64
#  38  PercentLackOfCohesion      1834 non-null   int64
#  39  MaxInheritanceTree         1834 non-null   int64
#  40  CountClassDerived          1834 non-null   int64
#  41  CountClassCoupled          1834 non-null   int64
#  42  CountClassBase             1834 non-null   int64
#  43  CountInput_Max             1834 non-null   int64
#  44  CountInput_Mean            1834 non-null   float64
#  45  CountInput_Min             1834 non-null   int64
#  46  CountOutput_Max            1834 non-null   int64
#  47  CountOutput_Mean           1834 non-null   float64
#  48  CountOutput_Min            1834 non-null   int64
#  49  CountPath_Max              1834 non-null   int64
#  50  CountPath_Mean             1834 non-null   float64
#  51  CountPath_Min              1834 non-null   int64
#  52  MaxNesting_Max             1834 non-null   int64
#  53  MaxNesting_Mean            1834 non-null   float64
#  54  MaxNesting_Min             1834 non-null   int64
#  55  COMM                       1834 non-null   int64
#  56  ADEV                       1834 non-null   int64
#  57  DDEV                       1834 non-null   int64
#  58  Added_lines                1834 non-null   int64
#  59  Del_lines                  1834 non-null   int64
#  60  OWN_LINE                   1834 non-null   float64
#  61  OWN_COMMIT                 1834 non-null   float64
#  62  MINOR_COMMIT               1834 non-null   int64
#  63  MINOR_LINE                 1834 non-null   int64
#  64  MAJOR_COMMIT               1834 non-null   int64
#  65  MAJOR_LINE                 1834 non-null   int64
#  66  HeuBug                     1834 non-null   bool
#  67  HeuBugCount                1834 non-null   int64
#  68  RealBug                    1834 non-null   bool
#  69  RealBugCount               1834 non-null   int64
# dtypes: bool(2), float64(7), int64(60), object(1)
# memory usage: 978.0+ KB

# %%
df.shape
# Out:
# (1834, 70)

# %%
#Defective and Non-defective Class histogram
import matplotlib.pyplot as plt

# Count the occurrences of each class
class_counts = df['RealBug'].value_counts()

# Plot the histogram
plt.bar(class_counts.index, class_counts.values)
plt.xlabel('Class')
plt.ylabel('Frequency')
plt.title('Defective and Non-defective Class histogram')
plt.xticks(rotation=0)
# show more numbers in frequency (y axis)
plt.gca().set_yticks(range(0, class_counts.max() + 50, 50))
# show the grid
# plt.grid(axis='y')
plt.show()

# %%
class_counts
# Out:
# RealBug
# False    1351
# True      483
# Name: count, dtype: int64

# %%
# Dispersion plot of class Defective
import seaborn as sns

sns.stripplot(x='RealBug', y='CountLineCode', data=df, jitter=True)
# Out:
# <Axes: xlabel='RealBug', ylabel='CountLineCode'>

# %%
    # Suponiendo que las columnas relevantes para la visualización se llaman 'metric_1', 'metric_2' y 'class'
# Reemplaza 'metric_1' y 'metric_2' con los nombres reales de las columnas que quieres visualizar.
# 'class' es la columna que contiene la etiqueta de clase (defecto o no defecto).
sns.scatterplot(x='CountLineCode', y='AvgCyclomatic', hue='RealBug', data=df)

# Añadir títulos y etiquetas
plt.title('Gráfico de dispersión por clase')
plt.xlabel('Líneas de código (LOC)')
plt.ylabel('Complejidad ciclomática')
plt.show()
